# %%
from PIL import Image
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
im = Image.open("flowers/raw-data/train/daisy/22873310415_3a5674ec10_m.jpg")

# %%
plt.imshow(im)

# %%
im = Image.open("flowers/raw-data/train/dandelion/20165867412_fc45d31698_m.jpg")
plt.imshow(im)

# %%
im = Image.open("flowers/raw-data/train/roses/2065522422_cfdd80044a_n.jpg")
plt.imshow(im)

# %%
im = Image.open("flowers/raw-data/train/sunflowers/22405882322_d4561f8469_n.jpg")
plt.imshow(im)

# %%
im = Image.open("flowers/raw-data/train/tulips/16471277547_a0a5509377_n.jpg")
plt.imshow(im)
